# %%
a = (1,2,3,2,5,1,2)
ind = [0]*0
for i in range(len(a)):
    if a[i] == 2:
        ind.append(i)
ind
# Out:
# [1, 3, 6]

# %%
dicDummy = dict({'A':12,'B':23,'C':45})
# d = dicDummy.fromkeys(['A','B'])
# d

# %%
# d = dDummy.fromkeys([1,3,6,8])
# print(True if dicDummy.pop('A') else False)
dicDummy.popitem()
# Out:
# ('C', 45)

# %%
list(dicDummy.values())
# Out:
# [12, 23]

# %%
dicDummy.items()
# Out:
# dict_items([('A', 12), ('B', 23)])

# %%
dicDummy.keys()
# Out:
# dict_keys(['A', 'B'])

# %%
import time
import matplotlib.pyplot as plt

# %%
def timeit(func):
    start_time = time.time()
    func()
    endtime = time.time()-start_time
    return func()

# %%
time_x = {"Time":[],"Itr":[]}
import random
@timeit
def timeExp():
    for i in range(100000):
        start= time.perf_counter()
        fruitList = [x for x in range(i)]
        # print(type(fruitList))
        # [print(fruit,end=", ") for fruit in fruitList]

        fruitTuple = tuple(fruitList)
        # print("\n",type(fruitTuple))
        # for fruit in fruitTuple:
            # print(fruit,end=", ") 
            # Can't use list comprehension as print() always returns none
            # So output will be [None, None,...,None] -> len(tuple)
        endtime = time.perf_counter()-start

        time_x['Time'].append(endtime)
        time_x['Itr'].append(i)

    plt.scatter(time_x['Itr'],time_x['Time'])
